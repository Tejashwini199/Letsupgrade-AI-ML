# %% [markdown]
# Assignment_day_11

# %%
import pandas as pd

# %%
dataset = pd.read_csv("general_data.csv")

# %%
dataset
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
# checking for null values
dataset.replace(to_replace=['NA',],value=[0],inplace = True)
dataset.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
# checking element of row has null value
dataset = dataset.dropna()
dataset
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %% [markdown]
# Now we go with our main objective to compare attrition with remaining fields

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
print("Attrition:",dataset.Attrition.unique())
print("BusinessTravel:",dataset.BusinessTravel.unique())
print("Department:",dataset.Department.unique())
print("EducationField:",dataset.EducationField.unique())
print("Gender:",dataset.Gender.unique())
print("JobRole:",dataset.JobRole.unique())
print("MaritalStatus:",dataset.MaritalStatus.unique())
print("Over18:",dataset.Over18.unique())
# Out:
# Attrition: ['No' 'Yes']
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department: ['Sales' 'Research & Development' 'Human Resources']
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender: ['Female' 'Male']
# JobRole: ['Healthcare Representative' 'Research Scientist' 'Sales Executive'
#  'Human Resources' 'Research Director' 'Laboratory Technician'
#  'Manufacturing Director' 'Sales Representative' 'Manager']
# MaritalStatus: ['Married' 'Single' 'Divorced']
# Over18: ['Y']

# %%
dataset.replace(to_replace=['Yes','No'],value=[1,0],inplace = True)
dataset.replace(to_replace=['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'],value=[2,1,0],inplace = True)
dataset.replace(to_replace=['Sales', 'Research & Development', 'Human Resources'],value=[2,1,0],inplace = True)
dataset.replace(to_replace=['Life Sciences', 'Other', 'Medical', 'Marketing', 'Technical Degree',
 'Human Resources'],value=[5,4,3,2,1,0],inplace = True)
dataset.replace(to_replace=['Female', 'Male'],value=[1,0],inplace = True)
dataset.replace(to_replace=['Healthcare Representative', 'Research Scientist', 'Sales Executive',
 'Human Resources', 'Research Director', 'Laboratory Technician',
 'Manufacturing Director', 'Sales Representative', 'Manager'],value=[8,7,6,5,4,3,2,1,0],inplace = True)
dataset.replace(to_replace=['Married', 'Single', 'Divorced'],value=[2,1,0],inplace = True)
dataset.replace(to_replace=['Y', 'N'],value=[1,0],inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
dataset
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51          0               2           2                 6          2
# 1      31          1               1           1                10          1
# 2      32          0               1           1                17          4
# 3      38          0               0           1                 2          5
# 4      32          0               2           1                10          1
# ...   ...        ...             ...         ...               ...        ...
# 4404   29          0               2           2                 4          3
# 4405   42          0               2           1                 5          4
# 4406   29          0               2           1                 2          4
# 4407   25          0               2           1                25          2
# 4408   42          0               2           2                18          2
#
# ...

# %%
from scipy.stats import pearsonr

# %%
dataset
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51          0               2           2                 6          2
# 1      31          1               1           1                10          1
# 2      32          0               1           1                17          4
# 3      38          0               0           1                 2          5
# 4      32          0               2           1                10          1
# ...   ...        ...             ...         ...               ...        ...
# 4404   29          0               2           2                 4          3
# 4405   42          0               2           1                 5          4
# 4406   29          0               2           1                 2          4
# 4407   25          0               2           1                25          2
# 4408   42          0               2           2                18          2
#
# ...

# %%
dataset.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.158399        0.025044   -0.012117
# Attrition               -0.158399   1.000000        0.000825   -0.044624
# BusinessTravel           0.025044   0.000825        1.000000   -0.009163
# Department              -0.012117  -0.044624       -0.009163    1.000000
# DistanceFromHome         0.007376  -0.009449        0.025066    0.012095
# Education               -0.033900  -0.017106        0.003074   -0.003732
# EducationField          -0.000243  -0.003564       -0.036274   -0.059843
# EmployeeCount                 NaN        NaN             NaN         NaN
# EmployeeID               0.008105  -0.004621       -0.003193   -0.001500
# Gender                   0.040625  -0.018396        0.038942   -0.002680
# JobLevel                -0.001137  -0.012382        0.045873    0.004290
# JobRole                 -0.022923   0.033642       -0.019420    0.020453
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
stat1,p1=pearsonr(dataset.Attrition,dataset.Age)
print(stat1,p1)
# Out:
# -0.1583986795409671 5.1265982193780794e-26

# %%
stat2,p2=pearsonr(dataset.Attrition,dataset.DistanceFromHome)
print(stat2,p2)
# Out:
# -0.009448638515156291 0.5317715668018396

# %%
for i in dataset.columns :
    if i not in ['Attrition','EmployeeID','EmployeeCount','StandardHours','NumCompaniesWorked','TotalWorkingYears'] :
        temp,p = pearsonr(dataset.Attrition,dataset[i])
        print(i,end=": ")
        print(temp,p,end="\n\n")
# Out:
# Age: -0.1583986795409671 5.1265982193780794e-26
#
# BusinessTravel: 0.0008247972174227641 0.9564704697198688
#
# Department: -0.0446237516075301 0.0031310203124893265
#
# DistanceFromHome: -0.009448638515156291 0.5317715668018396
#
# Education: -0.01710630705027876 0.25757539308157945
#
# EducationField: -0.0035640724985355437 0.8135388293465787
#
# Gender: -0.01839642519444091 0.22339966086831062
#
# JobLevel: -0.012381569720790884 0.4125489150380087
#
# JobRole: 0.03364210388009886 0.02594791116636604
#
# MaritalStatus: -0.010885951471658504 0.47126055129955585
#
# MonthlyIncome: -0.030160293808460668 0.045890862744719166
#
# Over18: nan nan
#
# PercentSalaryHike: 0.033153037135466544 0.028192446935112747
#
# StockOptionLevel: -0.008164026684984288 0.588999635831226
#
# TrainingTimesLastYear: -0.04758573693081715 0.0016276603635466457
#
# YearsAtCompany: -0.13300261842521535 9.476118084840815e-19
#
# YearsSinceLastPromotion: -0.03142315056330998 0.03752293607394324
#
# ...

# %% [markdown]
# --There is no field with perfect positive or negative correlation
#
# --Since p of Age is < 0.05 H0 is rejected and can conclude they are correlated
#
# --Since p of BusinessTravel is > 0.05 H0 is accepted i.e; both are correlated
#
# --Since p of Department is < 0.05 H0 is rejected
#
# ........ and remaining can be concluded as above

# %%
dataset.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.158399        0.025044   -0.012117
# Attrition               -0.158399   1.000000        0.000825   -0.044624
# BusinessTravel           0.025044   0.000825        1.000000   -0.009163
# Department              -0.012117  -0.044624       -0.009163    1.000000
# DistanceFromHome         0.007376  -0.009449        0.025066    0.012095
# Education               -0.033900  -0.017106        0.003074   -0.003732
# EducationField          -0.000243  -0.003564       -0.036274   -0.059843
# EmployeeCount                 NaN        NaN             NaN         NaN
# EmployeeID               0.008105  -0.004621       -0.003193   -0.001500
# Gender                   0.040625  -0.018396        0.038942   -0.002680
# JobLevel                -0.001137  -0.012382        0.045873    0.004290
# JobRole                 -0.022923   0.033642       -0.019420    0.020453
# ...
